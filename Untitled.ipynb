# %%
from nba_api.stats.endpoints import boxscorescoringv2
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.endpoints import playergamelog

# %%
nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
celtics = [team for team in nba_teams if team['abbreviation'] == 'LAL'][0]
celtics_id = celtics['id']

# %%
# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION           TEAM_NAME     GAME_ID  \
# 0     22018  1610612747               LAL  Los Angeles Lakers  0021800453
# 1     22018  1610612747               LAL  Los Angeles Lakers  0021800439
# 2     22018  1610612747               LAL  Los Angeles Lakers  0021800430
# 3     22018  1610612747               LAL  Los Angeles Lakers  0021800416
# 4     22018  1610612747               LAL  Los Angeles Lakers  0021800401
#
#     GAME_DATE      MATCHUP WL  MIN  PTS     ...      FT_PCT  OREB  DREB   REB  \
# 0  2018-12-18    LAL @ BKN  L  240  110     ...       0.565   8.0  40.0  48.0
# 1  2018-12-16    LAL @ WAS  L  242  110     ...       0.611   8.0  35.0  43.0
# 2  2018-12-15    LAL @ CHA  W  240  128     ...       0.667  10.0  42.0  52.0
# 3  2018-12-13    LAL @ HOU  L  240  111     ...       0.556   7.0  24.0  31.0
# 4  2018-12-10  LAL vs. MIA  W  242  108     ...       0.600  12.0  34.0  46.0
#
#    AST   STL  BLK   TOV  PF  PLUS_MINUS
# ...

# %%
boxscore = boxscorescoringv2.BoxScoreScoringV2('0021800453')
df = boxscore.get_data_frames()[0]

# %%
df.head()
# Out:
#       GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0  0021800453  1610612747               LAL  Los Angeles       2544
# 1  0021800453  1610612747               LAL  Los Angeles    1628398
# 2  0021800453  1610612747               LAL  Los Angeles       2199
# 3  0021800453  1610612747               LAL  Los Angeles    1628404
# 4  0021800453  1610612747               LAL  Los Angeles    1628366
#
#       PLAYER_NAME START_POSITION COMMENT    MIN  PCT_FGA_2PT      ...       \
# 0    LeBron James              F          41:12        0.696      ...
# 1      Kyle Kuzma              F          42:36        0.619      ...
# 2  Tyson Chandler              C          17:08        1.000      ...
# 3       Josh Hart              G          34:21        0.500      ...
# 4      Lonzo Ball              G          39:25        0.438      ...
#
#    PCT_PTS_FB  PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  \
# ...

# %%
player = playergamelog.PlayerGameLog(2544,date_from_nullable='12/15/2018',date_to_nullable='12/20/2018')
df2 = player.get_data_frames()[0]
df2.head()
# Out:
#   SEASON_ID  Player_ID     Game_ID     GAME_DATE    MATCHUP WL  MIN  FGM  FGA  \
# 0     22018       2544  0021800453  DEC 18, 2018  LAL @ BKN  L   41   13   23
# 1     22018       2544  0021800439  DEC 16, 2018  LAL @ WAS  L   32    5   16
# 2     22018       2544  0021800430  DEC 15, 2018  LAL @ CHA  W   30    7   15
#
#    FG_PCT       ...         DREB  REB  AST  STL  BLK  TOV  PF  PTS  \
# 0   0.565       ...           12   13    8    1    1    5   1   36
# 1   0.313       ...            6    6    3    0    1    4   0   13
# 2   0.467       ...           11   12   11    1    0    3   0   24
#
#    PLUS_MINUS  VIDEO_AVAILABLE
# 0           4                1
# 1         -21                1
# 2          31                1
#
# [3 rows x 27 columns]
